# %% [markdown]
# # CS 178 Project <br>
# ### Team 69 - "Adulting" <br>
# Members:<br>
# Dingyi Chang #89167697<br>
# Nicholas King #33099364<br>
# Jenny My Lee #11994579<br>

# %% [markdown]
# ## Import Libraries

# %%
#Import libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import sklearn.tree as tree
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import zero_one_loss
from sklearn.ensemble import RandomForestClassifier
from sklearn.impute import KNNImputer, SimpleImputer
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.model_selection import cross_val_score
from sklearn.pipeline import Pipeline
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# ## Collect Data

# %%
tr_url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data'
val_url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.test'

header = ["age", "working class", "final weight", "education", "education number", "marital status", "occupation", "relationship", "race", "sex", "capital gain", "capital loss", "hours per week", "native country"]

#Read training data from adult.data and make Xtr and Ytr. Missing values are replaced with NaN.
tr_data = pd.read_csv(tr_url, sep = ', ', header = None,  na_values='?', engine = 'python')
val_data = pd.read_csv(val_url, sep = ', ', header = None, skiprows = 1,  na_values='?', engine = 'python')

#Encode data to use models in
encoded_tr_data = tr_data.copy()
encoded_val_data = val_data.copy()

categorical_columns = list(tr_data.select_dtypes(include=['object']).columns)

for i in categorical_columns:
    encoded_tr_data[i] = LabelEncoder().fit_transform(tr_data[i])
    encoded_val_data[i] = LabelEncoder().fit_transform(val_data[i])

#Create X_raw and Y_raw
Xtr_raw = np.array(tr_data)[:, :14]
Ytr_raw = np.array(tr_data)[:, 14]
Xval_raw = np.array(val_data)[:, :14]
Yval_raw = np.array(val_data)[:, 14]

#Create standard Xtr and Ytr
encoded_tr_data = encoded_tr_data.astype("int").where(~tr_data.isna(), -1)
encoded_val_data = encoded_val_data.astype("int").where(~val_data.isna(), -1)
Xtr = np.array(encoded_tr_data)[:, :14]
Ytr = np.array(encoded_tr_data)[:, 14]
Xval = np.array(encoded_val_data)[:, :14]
Yval = np.array(encoded_val_data)[:, 14]

#Create Xtr_na and Ytr_na
encoded_tr_data = encoded_tr_data.astype("int").where(~tr_data.isna(), -1)
encoded_val_data = encoded_val_data.astype("int").where(~val_data.isna(), -1)
Xtr_na = np.array(encoded_tr_data)[:, :14]
Ytr_na = np.array(encoded_tr_data)[:, 14]
Xval_na = np.array(encoded_val_data)[:, :14]
Yval_na = np.array(encoded_val_data)[:, 14]

# %% [markdown]
# ## Missing Values
# We've noticed that our dataset has some missing values in the entries. <br> Below is a summary of each feature, the number of missing values of each feature, and the percentage of missing values of each feature.

# %%
arr_percent_missing = []
for i in range(Xtr_raw[0].size):
 num_missing = pd.isnull(Xtr_raw[:, i]).sum()
 percent_missing = num_missing / Xtr_raw.shape[0] * 100
 arr_percent_missing.append(percent_missing)
 print(f"Feature: {header[i]}, Number missing {num_missing}, Percent Missing: {percent_missing}")
 
plt.bar(header, arr_percent_missing)
plt.xticks(rotation=90)
plt.title("Percent Missing")
# Out:
# Feature: age, Number missing 0, Percent Missing: 0.0
# Feature: working class, Number missing 1836, Percent Missing: 5.638647461687294
# Feature: final weight, Number missing 0, Percent Missing: 0.0
# Feature: education, Number missing 0, Percent Missing: 0.0
# Feature: education number, Number missing 0, Percent Missing: 0.0
# Feature: marital status, Number missing 0, Percent Missing: 0.0
# Feature: occupation, Number missing 1843, Percent Missing: 5.660145572924664
# Feature: relationship, Number missing 0, Percent Missing: 0.0
# Feature: race, Number missing 0, Percent Missing: 0.0
# Feature: sex, Number missing 0, Percent Missing: 0.0
# Feature: capital gain, Number missing 0, Percent Missing: 0.0
# Feature: capital loss, Number missing 0, Percent Missing: 0.0
# Feature: hours per week, Number missing 0, Percent Missing: 0.0
# Feature: native country, Number missing 583, Percent Missing: 1.7904855501980899
# Text(0.5, 1.0, 'Percent Missing')

# %% [markdown]
# For each feature, we want to collect data points that have an unknown value for said feature and predict what feature they will be. <br>
#
# There are several methods which are recommendeded for filling in missing features. <br> The simplest, and most common, is to use the mean or median of the remaining values to fill in a missing value for a numerical feature. For categorical features, the mode is used instead. <br> Although this method is quite simple and fast, it has a few downsides, such as not being accurate, not accounting for the uncertainty of our data imputations, not accounting for the correlations between features, and possibly introducing bias. <br> We will first use mean/median imputation and examine the validation errors.

# %%
mean_imputer = SimpleImputer(strategy='mean', missing_values=-1)

# label_encoder = preprocessing.LabelEncoder()
# encoded_tr_data = np.copy(tr_data)
# encoded_val_data = np.copy(val_data)
# for i in range(tr_data[0].size):
#     if isinstance(tr_data[0, i], str):
#         label_encoder.fit(tr_data[:, i])
#         encoded_tr_data[:, i] = label_encoder.transform(tr_data[:, i])
#         label_encoder.fit(val_data[:, i])
#         encoded_val_data[:, i] = label_encoder.transform(val_data[:, i])

mean_imputer.fit(Xtr)
Xtr_trans_mean = (np.round(mean_imputer.transform(Xtr))).astype(int)
mean_model = RandomForestClassifier()
mean_model.fit(Xtr_trans_mean, Ytr)
mean_imputer_te = np.round(zero_one_loss(mean_model.predict(Xtr_trans_mean), Ytr), 4)
mean_imputer_ve = np.round(zero_one_loss(mean_model.predict(Xval), Yval), 4)
print("mean imputer training error:", mean_imputer_te)
print("mean imputer test error:", mean_imputer_ve)

median_imputer = SimpleImputer(strategy='median', missing_values=-1)
median_imputer.fit(Xtr)
Xtr_trans_median = median_imputer.transform(Xtr)
median_model = RandomForestClassifier()
median_model.fit(Xtr_trans_median, Ytr)
median_imputer_te = np.round(zero_one_loss(median_model.predict(Xtr_trans_median), Ytr), 4)
median_imputer_ve = np.round(zero_one_loss(median_model.predict(Xval), Yval), 4)
print("median imputer training error:", median_imputer_te)
print("median imputer test error:", median_imputer_ve)
# Out:
# mean imputer training error: 0.0
# mean imputer test error: 0.1419
# median imputer training error: 0.0001
# median imputer test error: 0.1453

# %% [markdown]
# Though results may vary due to the randomness of the classifer used, in our run we got a test error of 0.1419 using the mean imputer and a test error of 0.1453 using the median imputer.
#
# Another method is to use k-NN clusters to impute the missing values. We find the k nearest neighbors of the missing entry based on the non-missing features and then fills in the missing value with the average prediction. This method may be more accurate than using the mean/median/mode imputation method described above, depending on the dataset, but it is more computationally expensive. <br>
# Below we impute the missing values with k-NN clusters.

# %%
num_neighbors = [1,5,10,15,25,50,100]
# imputer = KNNImputer(n_neighbors=5, weights='uniform', metric='nan_euclidean')
# imputer.fit(Xtr)
# Xtr_transform = imputer.transform(Xtr)

imputer_te = []
imputer_ve = []

results = []

for n in num_neighbors:
    imputer = KNNImputer(n_neighbors = n, weights='uniform', metric='nan_euclidean',missing_values=-1)
    imputer.fit(Xtr)
    Xtr_trans = imputer.transform(Xtr)
    model = RandomForestClassifier()
    model.fit(Xtr_trans, Ytr)
    
    cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
    scores = cross_val_score(model, Xtr_trans, Ytr, scoring='accuracy', cv=cv, n_jobs=-1, error_score='raise')
     # store results
    results.append(scores)    
    imputer_te.append(np.round(zero_one_loss(model.predict(Xtr_trans), Ytr), 4))
    imputer_ve.append(np.round(zero_one_loss(model.predict(Xval), Yval), 4))
    
    
    print("k neighbors:", n, ", mean: ", np.mean(scores), ", std:", np.std(scores))


plt.boxplot(results, labels=num_neighbors, showmeans=True)
plt.xlabel("k Neighbors")
plt.ylabel("accuracy")

plt.show()

plt.plot(num_neighbors, imputer_te)
plt.plot(num_neighbors, imputer_ve)
plt.legend(["Training Error", "Validation Error"])
plt.xlabel("k Neighbors")
plt.ylabel("Error")
# Out:
# k neighbors: 1 , mean:  0.8575288071028015 , std: 0.005527832556914021
# k neighbors: 5 , mean:  0.8576722548322179 , std: 0.005572952761672039
# k neighbors: 10 , mean:  0.8575903138882875 , std: 0.005058722712206477
# k neighbors: 15 , mean:  0.8573957949073086 , std: 0.005000408854927642
# k neighbors: 25 , mean:  0.8580509861328098 , std: 0.0052677329285940495
# k neighbors: 50 , mean:  0.8583274366280199 , std: 0.005605928476470271
# k neighbors: 100 , mean:  0.8585730865819906 , std: 0.0054607445503879
# Text(0, 0.5, 'Error')

# %%
print(min(imputer_ve))
print(imputer_ve)
# Out:
# 0.1435
# [0.1467, 0.1435, 0.1446, 0.1448, 0.1441, 0.1464, 0.1456]

# %% [markdown]
# The mean classification accuracy is reported with each k value used for imputation.
# In this case, we can see that a k = 5 resulting in the best performance of about 85.7 percent accuracy with a test error of 0.1435. <br> This is lower than our result of 0.1419 for the mean imputer, so we choose the mean imputer to fill in our missing features.
#
# As shown, a box and whisker plot is created for each set of results, allowing the distribution of results to be compared.
# The plot suggest that there is not much difference in the k value when imputing the missing values, with minor fluctuations around the mean performance (green triangle).

# %%
mean_imputer = SimpleImputer(strategy='mean', missing_values=-1)
mean_imputer.fit(Xtr)
Xtr_trans = mean_imputer.transform(Xtr)

# %% [markdown]
# ## Decision Tree Classifier
# Since we are using nominal data, it may be a good idea to implement a decision tree as our machine learning model. The code below will implement a decision tree model at different max depths, $d \in \{1,...,50\}$, and plots the training and validation error.

# %%
d = list(range(1, 51))   #Depth values for our decision

#Arrays to store training and validation error
tree_te = []
tree_ve = []


#Implement decision trees
for i in d:
    learner = tree.DecisionTreeClassifier(max_depth = i, criterion ='entropy')
    
    learner.fit(Xtr_trans, Ytr)
    tree_te.append(np.round(zero_one_loss(learner.predict(Xtr_trans), Ytr), 4))
    tree_ve.append(np.round(zero_one_loss(learner.predict(Xval), Yval), 4))
    

#Plot
plt.plot(d, tree_te)
plt.plot(d, tree_ve)


plt.legend(["Training Error", "Validation Error"])
plt.xlabel("Tree Depth")
plt.ylabel("Error")

print('The best tree', tree_ve.index(min(tree_ve))+1, 'with error of', min(tree_ve))
# Out:
# The best tree 8 with error of 0.1438

# %% [markdown]
# What we notice from the graph is that the optimal range for our tree at around $d=7$ and $d=8$, with the values having validation error of under ``0.15``.

# %% [markdown]
# ## Random Forest Classifier
# Our next model will be to use random forests. The code below will implement a random forest with number of trees, $t \in \{1,...,50\} $ and $d = 8$, which then plots the training and validation error.

# %%
t = list(range(1, 51))   #Number of trees in forest
d = 8                    #Depth values for our decision

#Arrays to store training and validation error
forest_te = []
forest_ve = []

#Implement random forests
for i in t:
    learner = RandomForestClassifier(n_estimators = i, criterion ='entropy', max_depth = d)
    learner.fit(Xtr_trans, Ytr)
    forest_te.append(np.round(zero_one_loss(learner.predict(Xtr_trans), Ytr), 4))
    forest_ve.append(np.round(zero_one_loss(learner.predict(Xval), Yval), 4))

#Plot
plt.plot(t, forest_te)
plt.plot(t, forest_ve)
plt.legend(["Training Error", "Validation Error"])
plt.xlabel("Number of Trees")
plt.ylabel("Error")
# Out:
# Text(0, 0.5, 'Error')

# %%
print(forest_ve)
print(min(forest_ve))
print(forest_ve.index(min(forest_ve))+1)
# Out:
# [0.1571, 0.1663, 0.1482, 0.1491, 0.1462, 0.1459, 0.1452, 0.1458, 0.1437, 0.1446, 0.1434, 0.145, 0.1477, 0.144, 0.1427, 0.1455, 0.1437, 0.1434, 0.1448, 0.1438, 0.1456, 0.1446, 0.1451, 0.1442, 0.1437, 0.1434, 0.144, 0.144, 0.1436, 0.1437, 0.1441, 0.1447, 0.1441, 0.1431, 0.1434, 0.1438, 0.1439, 0.1429, 0.1437, 0.1446, 0.1442, 0.1442, 0.144, 0.1431, 0.1442, 0.1435, 0.1445, 0.1442, 0.1435, 0.1432]
# 0.1427
# 15

# %% [markdown]
# The minimum validation error we got using the Random Forest classifier was 0.1427. This was achieved by setting the number of trees as 15.

# %%
# BREAK DELETE THIS

# %% [markdown]
# ## Gradient Boosting
# Finally, we will explore gradient boosting in order to achieve better results in our model.

# %%
gradient_booster = GradientBoostingClassifier(learning_rate=0.1)
accuracies = cross_val_score(gradient_booster, Xtr_trans, Ytr, cv=5)
gradient_booster.fit(Xtr_trans, Ytr)

print("Train Score:",np.mean(accuracies))
print("Test Score:",gradient_booster.score(Xval,Yval))

result_dict_train = {}
result_dict_test = {}
result_dict_train["Gradient-Boost Default Train Score"] = np.mean(accuracies)
result_dict_test["Gradient-Boost Default Test Score"] = gradient_booster.score(Xval,Yval)
# Out:
# Train Score: 0.8644084916540006
# Test Score: 0.8648731650390025

# %%
grid = {
    'learning_rate':[0.01,0.05,0.1, 0.15],
    'n_estimators':np.arange(100,400,100),
}

gb = GradientBoostingClassifier()
gb_cv = GridSearchCV(gb, grid, cv = 4)
gb_cv.fit(Xtr_trans,Ytr)
print("Best Parameters:",gb_cv.best_params_)
print("Score:",gb_cv.best_score_)
# print("Test Score:",gb_cv.score(Xval,Yval))

result_dict_train["Gradient-Boost GridSearch Train Score"] = gb_cv.best_score_
result_dict_test["Gradient-Boost GridSearch Test Score"] = gb_cv.score(Xval,Yval)
# Out:
# Best Parameters: {'learning_rate': 0.1, 'n_estimators': 300}
# Score: 0.8720863273743755
